# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
from wordcloud import WordCloud, ImageColorGenerator
import pandas as pd

# %%
filename = 'xmas'
maskImage = np.array(Image.open('./assets/smiley.jpg'))
shape = maskImage.shape
bgImage = ImageColorGenerator(np.array(Image.open('./assets/smile.png').resize((shape[0], shape[1]), Image.ANTIALIAS)))
data = pd.read_csv(f'../public/dataset/{filename}.csv').set_index('text').to_dict()['frequency']

# %%
maskImage.shape
# Out:
# (866, 938, 3)

# %%
wc = WordCloud( mask=maskImage, width=800, height=800, font_path='../public/font/NotoSans.ttf', background_color="white", max_words=1000)
wc.generate_from_frequencies(data)

# %%
def getColor(word='', font_size=None, position=None, orientation=None, random_state=None, font_path=None):
    return 'orange'

# %%
plt.figure(figsize=(20,20))
# plt.imshow(wc.recolor(color_func=bgImage), interpolation="bilinear")
plt.imshow(wc.recolor(color_func=getColor), interpolation='bilinear')
# plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
